# %% [markdown]
# <a href="https://colab.research.google.com/github/Aki55755/code/blob/main/A1_P3_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_table("/content/hi.txt")

# %%
df1
# Out:
# Empty DataFrame
# Columns: [akash]
# Index: []

# %%
data2 = pd.read_csv("/content/Book1.csv")

# %%
data2
# Out:
# Empty DataFrame
# Columns: [hello, 2303A51422]
# Index: []

# %%
data3 = pd.read_excel("/content/Book2.xlsx")

# %%
data3
# Out:
# Empty DataFrame
# Columns: [AIML SIR]
# Index: []
